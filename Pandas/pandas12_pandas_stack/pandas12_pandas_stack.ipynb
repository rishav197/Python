# %%
# Connect to Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Reshape dataframe using stack/unstack**

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/pandas12_pandas_stack/stocks.xlsx', header=[0, 1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df.stack()
# Out:
# /tmp/ipython-input-3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#             Unnamed: 0_level_0   Price  Price to earnings ratio (P/E)
# 0 Company           2017-06-05     NaN                            NaN
#   Facebook                 NaT   155.0                          37.10
#   Google                   NaT   955.0                          32.00
#   Microsoft                NaT    66.0                          30.31
# 1 Company           2017-06-06     NaN                            NaN
#   Facebook                 NaT   150.0                          36.98
#   Google                   NaT   987.0                          31.30
#   Microsoft                NaT    69.0                          30.56
# ...

# %%
# /content/drive/MyDrive/pandas12_pandas_stack/stocks.xlsx

# %%
df.stack(level=0)
# Out:
# /tmp/ipython-input-4116294391.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
# ...

# %%
df_stacked=df.stack()
df_stacked
# Out:
# /tmp/ipython-input-1126139389.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked=df.stack()
#             Unnamed: 0_level_0   Price  Price to earnings ratio (P/E)
# 0 Company           2017-06-05     NaN                            NaN
#   Facebook                 NaT   155.0                          37.10
#   Google                   NaT   955.0                          32.00
#   Microsoft                NaT    66.0                          30.31
# 1 Company           2017-06-06     NaN                            NaN
#   Facebook                 NaT   150.0                          36.98
#   Google                   NaT   987.0                          31.30
#   Microsoft                NaT    69.0                          30.56
# ...

# %%
df_stacked.unstack()
# Out:
#   Unnamed: 0_level_0                             Price                   \
#              Company Facebook Google Microsoft Company Facebook  Google
# 0         2017-06-05      NaT    NaT       NaT     NaN    155.0   955.0
# 1         2017-06-06      NaT    NaT       NaT     NaN    150.0   987.0
# 2         2017-06-07      NaT    NaT       NaT     NaN    153.0   963.0
# 3         2017-06-08      NaT    NaT       NaT     NaN    155.0  1000.0
# 4         2017-06-09      NaT    NaT       NaT     NaN    156.0  1012.0
#
#             Price to earnings ratio (P/E)
#   Microsoft                       Company Facebook Google Microsoft
# 0      66.0                           NaN    37.10   32.0     30.31
# 1      69.0                           NaN    36.98   31.3     30.56
# 2      62.0                           NaN    36.78   31.7     30.46
# 3      61.0                           NaN    36.11   31.2     30.11
# 4      66.0                           NaN    37.07   30.0     31.00

# %% [markdown]
# ### **3 levels of column headers**

# %%
df2 = pd.read_excel('/content/drive/MyDrive/pandas12_pandas_stack/stocks_3_levels.xlsx', header=[0, 1, 2])
df2
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df2.stack()
# Out:
# /tmp/ipython-input-406340214.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2.stack()
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
#   Google                   NaN        987.0                         31.30
# ...

# %%
df2.stack(level=0)
# Out:
# /tmp/ipython-input-526338979.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2.stack(level=0)
#                      Unnamed: 0_level_1    Price                    \
#                                 Company Facebook  Google Microsoft
# 0 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    155.0   955.0      66.0
#   Unnamed: 0_level_0            Q1 2016      NaN     NaN       NaN
# 1 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    150.0   987.0      69.0
#   Unnamed: 0_level_0            Q2 2016      NaN     NaN       NaN
# 2 Income Statement                  NaN      NaN     NaN       NaN
# ...

# %%
df2.stack(level=1)
# Out:
# /tmp/ipython-input-492282230.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df2.stack(level=1)
#                                 Unnamed: 0_level_0 Price Ratios          \
#                                            Company     Facebook  Google
# 0 Net Profit                                   NaN          NaN     NaN
#   Net Sales                                    NaN          NaN     NaN
#   Price                                        NaN       155.00   955.0
#   Price to earnings ratio (P/E)                NaN        37.10    32.0
#   Unnamed: 0_level_1                       Q1 2016          NaN     NaN
# 1 Net Profit                                   NaN          NaN     NaN
#   Net Sales                                    NaN          NaN     NaN
# ...
