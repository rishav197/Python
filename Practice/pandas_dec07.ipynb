# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Pandas Intro**

# %% [markdown]
# ### What is Data Science?<br> Data Science or data analytics is a process of analyzing large set of data points to get answers on questions related to that data set Pandas is a python module that makes data science easy and effective
#
# 1. What was max temperature in new york in the month january?
# 2. On which days did it rain?
# 3. What was average speed of wind during the month?

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Pandas/nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.8+ KB

# %% [markdown]
# Ques 1: What was max temperature in new york in the month january?

# %%
df['Temperature'].max()
# Out:
# 50

# %% [markdown]
# Ques 2: On which days did it rain ?

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %% [markdown]
# Ques 3: What was average speed of wind during this month ?

# %%
df.fillna(0, inplace=True)
df['WindDirDegrees'].mean()
# Out:
# np.float64(247.1290322580645)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df[df['Temperature']>40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           0.0             1.8           7   Rain
# 14                9           5.0               T           2      0
# 15                8           7.0            0.24           7   Rain
# ...

# %% [markdown]
# Process of Cleaning messy data is called data munging or data wrangling.

# %% [markdown]
# ### **Pandas02 DF basics**

# %% [markdown]
# ### What is Dataframe ?
#
# Dataframe is a main object in pandas. It is used to respresent data with rows and columns (tabular or excel spreadsheet like data)
#
# Topics
#
# 1. Creating dataframe
# 2. Dealing with rows and columns
# 3. Operations : min, max, std, describe
# 4. Conditional Selection
# 5. set_index

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas02_df_basics/weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ### Create dataframe using python dictionary

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017','1/4/2017','1/5/2017','1/6/2017'],
    'temperature': [32,35,28,24,32,31],
    'windspeed': [6,7,2,7,4,2],
    'event': ['Rain', 'Sunny', 'Snow','Snow','Rain', 'Sunny']
}

# %%
rows, cols = df.shape
print(rows)
print(cols)
# Out:
# 6
# 4

# %% [markdown]
# Use head() method

# %%
df.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# Use indexing and slicing in pd dataframe

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %% [markdown]
# df[:] or df is Same

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %% [markdown]
# Use describe() method

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %% [markdown]
# ### **Operations on Dataframe**

# %% [markdown]
# Conditional Select the data in your df

# %%
# Records when temperature is >= 32
df[df['temperature']>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
# Record when temperature is max

df[df['temperature']==df['temperature'].max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
# Record when temperature is min

df[df['temperature']==df['temperature'].min()]
# Out:
#         day  temperature  windspeed event
# 3  1/4/2017           24          7  Snow

# %%
# Day when temperature in max

df[df['temperature']==df['temperature'].max()][['day', 'temperature']]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %% [markdown]
# set_index

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day', inplace=True)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# Index(['1/1/2017', '1/2/2017', '1/3/2017', '1/4/2017', '1/5/2017', '1/6/2017'], dtype='object', name='day')

# %%
df.loc['1/1/2017']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 1/1/2017, dtype: object

# %%
print(df.loc['1/1/2017']['temperature'])
print(df.loc['1/1/2017']['windspeed'])
print(df.loc['1/1/2017']['event'])
# Out:
# 32
# 6
# Rain

# %%
df.reset_index(inplace=True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index('event', inplace=True)

# %%
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %%
df.loc['Sunny']
# Out:
#             day  temperature  windspeed
# event
# Sunny  1/2/2017           35          7
# Sunny  1/6/2017           31          2

# %%
df.loc['Rain']
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Rain   1/5/2017           32          4

# %% [markdown]
# ### **Diff ways of creating df**

# %% [markdown]
# Using CSV

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas03_diff_ways_of_creating_df/weather_data.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# Using Excel

# %%
df = pd.read_excel('/content/drive/MyDrive/pandas03_diff_ways_of_creating_df/weather_data.xlsx', 'Sheet1')
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %% [markdown]
# Using Dictionary

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}

df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# Using list of tuples

# %%
weather_data = [
    ('1/1/2017', 32, 6, 'Rain'),
    ('1/2/2017', 35, 7, 'Sunny'),
    ('1/3/2017', 28, 2, 'Snow')
]

df = pd.DataFrame(data=weather_data, columns=['day', 'temp', 'windspeed', 'event'])
df
# Out:
#         day  temp  windspeed  event
# 0  1/1/2017    32          6   Rain
# 1  1/2/2017    35          7  Sunny
# 2  1/3/2017    28          2   Snow

# %% [markdown]
# Using list of dictionaries

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
]

df = pd.DataFrame(data=weather_data, columns=['day', 'temp', 'windspeed', 'event'])
df
# Out:
#         day  temp  windspeed  event
# 0  1/1/2017   NaN          6   Rain
# 1  1/2/2017   NaN          7  Sunny
# 2  1/3/2017   NaN          2   Snow

# %% [markdown]
# ### Pandas04 : Read write excel csv file

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv', skiprows=2)
df
# Out:
#     WMT           4.61  484    65           n.a.
# 0  MSFT             -1   85    64     bill gates
# 1  RIL   not available   50  1023  mukesh ambani
# 2  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv', header=1) # skiprows and header are kind of same
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv', header=None, names = ["ticker","eps","revenue","people"])
df
# Out:
#                 ticker      eps revenue         people
# tickers            eps  revenue   price         people
# GOOGL            27.82       87     845     larry page
# WMT               4.61      484      65           n.a.
# MSFT                -1       85      64     bill gates
# RIL      not available       50    1023  mukesh ambani
# TATA               5.6       -1    n.a.     ratan tata

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv',  nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv', na_values=['not available', 'n.a.', -1])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.csv', na_values={
  'eps': ['not available'],
  'revenue': [-1],
  'people': ['not available', 'n.a.'],
  'price': ['n.a.']})

df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df.isnull().sum()
# Out:
# tickers    0
# eps        1
# revenue    1
# price      1
# people     1
# dtype: int64

# %% [markdown]
# ### Write to CSV

# %%
df.to_csv('new.csv', index=False)

# %%
df.to_csv('new.csv', header=False)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv('new.csv', columns=['tickers', 'eps', 'price'], index=False)

# %% [markdown]
# Read Excel

# %%
df = pd.read_excel('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.xlsx', 'Sheet1')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
  if cell=='n.a.':
    return 'Sam Walton'

  return cell


def convert_price_cell(cell):
  if cell=='n.a.':
    return 50
  return cell

# %%
df = pd.read_excel('/content/drive/MyDrive/pandas04_read_write_excel_csv_file/stock_data.xlsx', 'Sheet1', converters={
    'people': convert_people_cell,
    'price': convert_price_cell
})

# %%
df
# Out:
#   tickers            eps  revenue  price         people
# 0   GOOGL          27.82       87    845     larry page
# 1     WMT           4.61      484     65     Sam Walton
# 2    MSFT             -1       85     64     bill gates
# 3    RIL   not available       50   1023  mukesh ambani
# 4    TATA            5.6       -1     50     ratan tata

# %%
df.to_excel("new.xlsx", sheet_name="stocks")

# %%
df.to_excel("new.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
  df_stocks.to_excel(writer, sheet_name="stocks")
  df_weather.to_excel(writer, sheet_name="weather")

# %% [markdown]
# #### **Pandas05 : handling missing data fillna**

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas05_handling_missing_data/weather_data.csv', parse_dates=['day'])
df.set_index('day', inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9 entries, 2017-01-01 to 2017-01-11
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  5 non-null      float64
#  1   windspeed    5 non-null      float64
#  2   event        7 non-null      object
# dtypes: float64(2), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# **fillna**

# %% [markdown]
# Fill all NaN with one specific value

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna({
    'temperature': 0,
    'windspeed': 0,
    'event': 'No Event'
})

new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  No Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %% [markdown]
# Use method to determine how to fill na values

# %%
# forward fill
new_df = df.fillna(method='ffill')
new_df
# Out:
# /tmp/ipython-input-1356776736.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method='ffill')
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# backward fill
new_df = df.fillna(method='bfill')
new_df
# Out:
# /tmp/ipython-input-889031882.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method='bfill')
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Limit Parameter

# %%
new_df = df.fillna(method='ffill', limit=1)
new_df
# Out:
# /tmp/ipython-input-353201514.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method='ffill', limit=1)
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Use of axis

# %%
new_df = df.fillna(method='bfill', axis='columns') # axis is either 'index' or 'columns'
new_df
# Out:
# /tmp/ipython-input-2716125934.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method='bfill', axis='columns') # axis is either 'index' or 'columns'
# /tmp/ipython-input-2716125934.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df = df.fillna(method='bfill', axis='columns') # axis is either 'index' or 'columns'
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         9.0       9.0   Sunny
# 2017-01-05        28.0      Snow    Snow
# 2017-01-06         7.0       7.0     NaN
# 2017-01-07        32.0      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# ...

# %% [markdown]
# interpolate

# %%
new_df = df.interpolate(method='time')
new_df
# Out:
# /tmp/ipython-input-3316049018.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method='time')
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %% [markdown]
# drop na

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Inserting Missing Dates

# %%
dt = pd.date_range('01-01-2017', '01-11-2017')
idx = pd.DatetimeIndex(dt)
new_df = df.reindex(idx)
new_df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Replacing Single Value

# %%
import numpy as np

# %%
new_df = df.replace(-99999, np.nan)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Replacing List with Single Value

# %%
new_df = df.replace([-99999, '0'], np.nan)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Replacing per column

# %%
df.columns
# Out:
# Index(['temperature', 'windspeed', 'event'], dtype='object')

# %%
new_df = df.replace({
    'temperature': -99999,
    'windspeed': -99999,
    'event': '0'
}, np.nan)

new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Replacing by using mapping

# %%
new_df = df.replace({
    -99999: np.nan,
    '0': 'Sunny'
})

new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# Replacing using RegEx (Regular Expression)

# %%
df_regex = pd.read_excel('/content/drive/MyDrive/pandas06_handling_missing_data/weather_data_regex.xlsx')
df_regex
# Out:
#          day temperature windspeed  event
# 0 2017-01-01        32 F     6 mph   Rain
# 1 2017-02-01      -99999     7 mph  Sunny
# 2 2017-03-01          28    -99999   Snow
# 3 2017-04-01      -99999         7      0
# 4 2017-05-01        32 C    -99999   Rain
# 5 2017-06-01          31         2  Sunny
# 6 2017-06-01          34         5      0

# %%
# when windspeed is 6 mph, 7 mph etc. & temperature is 32 F, 28 F etc.
new_df = df_regex.replace({'temperature': '[A-Za-z]', 'windspeed': '[a-z]'}, '', regex=True)
new_df
# Out:
#          day temperature windspeed  event
# 0 2017-01-01         32         6    Rain
# 1 2017-02-01      -99999        7   Sunny
# 2 2017-03-01          28    -99999   Snow
# 3 2017-04-01      -99999         7      0
# 4 2017-05-01         32     -99999   Rain
# 5 2017-06-01          31         2  Sunny
# 6 2017-06-01          34         5      0

# %% [markdown]
# Replacing list with another list

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})

df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
# /tmp/ipython-input-4027045839.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %% [markdown]
# ### **Pandas07 : Group by**

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas07_groupby/weather_by_cities.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %% [markdown]
# For this dataset, get following answers,
#
# 1. What was the maximum temperature in each of these 3 cities?
# 2. What was the average windspeed in each of these 3 cities?

# %%
g = df.groupby('city')
g

# %%
for city, city_df in g:
  print(city)
  print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
g.get_group('paris')
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('new york')
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.min()
# Out:
#                day  temperature  windspeed   event
# city
# mumbai    1/1/2017           85          5     Fog
# new york  1/1/2017           28          6    Rain
# paris     1/1/2017           42          8  Cloudy

# %%
g.mean(numeric_only=True)
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
g.size()
# Out:
# city
# mumbai      4
# new york    4
# paris       4
# dtype: int64

# %%
g.count()
# Out:
#           day  temperature  windspeed  event
# city
# mumbai      4            4          4      4
# new york    4            4          4      4
# paris       4            4          4      4

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# Group data using custom function: Let's say you want to group your data using custom function. Here the requirement is to create three groups
#
# 1. Days when temperature was between 80 and 90
# 2. Days when it was between 50 and 60
# 3. Days when it was anything else
#
# For this you need to write custom grouping function and pass that to groupby

# %%
def grouper(df, idx, col):
  if 80 <= df[col].loc[idx] <= 90:
    return '80-90'
  elif 50 <= df[col].loc[idx] <= 60:
    return '50-60'
  else:
    return 'others'

# %%
print(df['temperature'].loc[11])
print(grouper(df, 11, 'temperature'))
print(grouper(df, 4, 'temperature'))
print(grouper(df, 10, 'temperature'))
# Out:
# 42
# others
# 80-90
# 50-60

# %%
g = df.groupby(lambda x : grouper(df, x, 'temperature'))
g

# %%
for key, d in g:
  print("Group by Key: {}\n".format(key))
  print(d)
# Out:
# Group by Key: 50-60
#
#          day   city  temperature  windspeed   event
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# Group by Key: 80-90
#
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# Group by Key: others
#
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 11  1/4/2017     paris           42         10  Cloudy

# %% [markdown]
# **1. What was the maximum temperature in each of these 3 cities?**

# %%
df.groupby('city')['temperature'].mean()
# Out:
# city
# mumbai      88.50
# new york    32.25
# paris       47.75
# Name: temperature, dtype: float64

# %% [markdown]
# 2. What was the average windspeed in each of these 3 cities ?

# %%
df.groupby('city')['windspeed'].mean()
# Out:
# city
# mumbai       9.25
# new york     8.00
# paris       12.75
# Name: windspeed, dtype: float64

# %%
# df.groupby('city')['windspeed'].count()

# %% [markdown]
# ### **Pandas08 : Pandas Concat**

# %%
india_weather = pd.DataFrame({
    'city':['mumbai', 'delhi', 'banglore'],
    'temperature': [32, 45, 30],
    'humidity': [80, 60, 78]
})

india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})

us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
pd.concat([india_weather, us_weather])
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# Ignore index

# %%
# it ignore indices of previous dataframes
df = pd.concat([india_weather, us_weather], ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
df.sample(frac=1).reset_index(drop=True)
# Out:
#        city  temperature  humidity
# 0   chicago           14        65
# 1  new york           21        68
# 2  banglore           30        78
# 3    mumbai           32        80
# 4     delhi           45        60
# 5   orlando           35        75

# %% [markdown]
# Concatenation and Keys

# %%
df = pd.concat([india_weather, us_weather], keys=['india', 'us'])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc['us']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df.loc['india']
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
df.loc['india'].loc[:1]
# Out:
#      city  temperature  humidity
# 0  mumbai           32        80
# 1   delhi           45        60

# %% [markdown]
# Concatenation using index

# %%
temp_df = pd.DataFrame({
    'city': ['mumbai', 'delhi', 'banglore'],
    'temperature': [32, 45, 30]
}, index=[1,2,3])

temp_df
# Out:
#        city  temperature
# 1    mumbai           32
# 2     delhi           45
# 3  banglore           30

# %%
windspeed_df = pd.DataFrame({
    'city': ['delhi', 'mumbai'],
    'windspeed': [7, 12]
}, index=[0,1])

windspeed_df
# Out:
#      city  windspeed
# 0   delhi          7
# 1  mumbai         12

# %%
df = pd.concat([temp_df, windspeed_df], axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 1    mumbai         32.0  mumbai       12.0
# 2     delhi         45.0     NaN        NaN
# 3  banglore         30.0     NaN        NaN
# 0       NaN          NaN   delhi        7.0

# %% [markdown]
# ### **Pandas09 : Pandas merge**

# %% [markdown]
# Basic Merge using a common col in dfs

# %%
df1 = pd.DataFrame({
    'city': ['new york', 'chicago', 'orlando'],
    'temperature': [21, 14, 35]
})

df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    'city': ["chicago","new york","orlando"],
    'humidity': [65, 68, 75]
})

df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
new_df = pd.merge(df1, df2, on='city') # By default it'll be inner join
new_df
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# Types of DB joins

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})

df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})

df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %% [markdown]
# INNER Join

# %%
new_df = pd.merge(df1, df2, on='city', how='inner')
new_df
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %% [markdown]
# OUTER Join

# %%
pd.merge(df1, df2, on='city', how='outer')
# Out:
#         city  temperature  humidity
# 0  baltimore         38.0       NaN
# 1    chicago         14.0      65.0
# 2   new york         21.0      68.0
# 3    orlando         35.0       NaN
# 4  san diego          NaN      71.0

# %% [markdown]
# LEFT Join

# %%
pd.merge(df1, df2, on='city', how='left')
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %% [markdown]
# RIGHT Join

# %%
pd.merge(df1, df2, on='city', how='right', indicator=True)
# Out:
#         city  temperature  humidity      _merge
# 0    chicago         14.0        65        both
# 1   new york         21.0        68        both
# 2  san diego          NaN        71  right_only

# %% [markdown]
# Indicator flag

# %%
pd.merge(df1, df2, on='city', how='outer', indicator=True)
# Out:
#         city  temperature  humidity      _merge
# 0  baltimore         38.0       NaN   left_only
# 1    chicago         14.0      65.0        both
# 2   new york         21.0      68.0        both
# 3    orlando         35.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %% [markdown]
# Suffixes

# %%
df1 = pd.DataFrame({
    'city': ["new york","chicago","orlando", "baltimore"],
    'temperature': [21,14,35,38],
    'humidity': [65,68,71, 75]
})

df1
# Out:
#         city  temperature  humidity
# 0   new york           21        65
# 1    chicago           14        68
# 2    orlando           35        71
# 3  baltimore           38        75

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "temperature": [21,14,35],
    "humidity": [65,68,71]
})

df2
# Out:
#         city  temperature  humidity
# 0    chicago           21        65
# 1   new york           14        68
# 2  san diego           35        71

# %%
pd.merge(df1, df2, on='city', how='outer', suffixes=('_left', '_right'))
# Out:
#         city  temperature_left  humidity_left  temperature_right  \
# 0  baltimore              38.0           75.0                NaN
# 1    chicago              14.0           68.0               21.0
# 2   new york              21.0           65.0               14.0
# 3    orlando              35.0           71.0                NaN
# 4  san diego               NaN            NaN               35.0
#
#    humidity_right
# 0             NaN
# 1            65.0
# 2            68.0
# 3             NaN
# 4            71.0

# %% [markdown]
# Join
#
# 1. .join() is a Pandas DataFrame method used to combine two DataFrames side by side (column-wise), usually aligning them by the index.
#
# 2. It’s similar to a SQL join but by default it works on the index, unless you specify otherwise.

# %%
df1 = pd.DataFrame({
     'city': ["new york","chicago","orlando", "LA"],
     'temperature': [21,14,35, 40]
 })

df1.set_index('city', inplace=True)
df1
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35
# LA                 40

# %%
df2 = pd.DataFrame({
    'city': ["chicago","new york","orlando"],
    'humidity': [65,68,75]
})

df2.set_index('city', inplace=True)
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
df1.join(df2, lsuffix='_l', rsuffix='_r')
# Out:
#           temperature  humidity
# city
# new york           21      68.0
# chicago            14      65.0
# orlando            35      75.0
# LA                 40       NaN

# %% [markdown]
# ### **Pandas10 : pandas pivot**

# %% [markdown]
# ### Pivot basics
#
# Pivot allows you to transform or reshape data

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas10_pandas_pivot/weather.csv')
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='city', columns='date')
# Out:
#          temperature                   humidity
# date        5/1/2017 5/2/2017 5/3/2017 5/1/2017 5/2/2017 5/3/2017
# city
# beijing           80       77       79       26       30       35
# mumbai            75       78       82       80       83       85
# new york          65       66       68       56       58       60

# %%
# when values='humidity'
df.pivot(index='city', columns='date', values='humidity')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %%
# when values='temperature'
df.pivot(index='city', columns='date', values='humidity')
# Out:
# date      5/1/2017  5/2/2017  5/3/2017
# city
# beijing         26        30        35
# mumbai          80        83        85
# new york        56        58        60

# %% [markdown]
# Pivot Table
#
# pivot table is used to summarize and aggregate data inside df

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas10_pandas_pivot/weather2.csv')
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index='city', columns='date')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# Margins

# %%
df.pivot_table(index='city', columns='date', margins=True, aggfunc='sum')
# Out:
#          humidity               temperature
# date     5/1/2017 5/2/2017  All    5/1/2017 5/2/2017  All
# city
# mumbai        163      111  274         153      162  315
# new york      110      122  232         126      142  268
# All           273      233  506         279      304  583

# %%
df.pivot_table(index='city', columns='date', margins=True, aggfunc=['mean', 'sum'])
# Out:
#              mean                                                   sum  \
#          humidity                 temperature                  humidity
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All 5/1/2017
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750      163
# new york    55.00    61.00  58.00       63.00     71.0  67.000      110
# All         68.25    58.25  63.25       69.75     76.0  72.875      273
#
#
#                        temperature
# date     5/2/2017  All    5/1/2017 5/2/2017  All
# city
# mumbai        111  274         153      162  315
# new york      122  232         126      142  268
# All           233  506         279      304  583

# %% [markdown]
# Grouper

# %%
df = pd.read_csv('/content/drive/MyDrive/pandas10_pandas_pivot/weather3.csv')
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
df.dtypes
# Out:
# date           object
# city           object
# temperature     int64
# humidity        int64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df['date']
# Out:
# 0   2017-05-01
# 1   2017-05-02
# 2   2017-05-03
# 3   2017-12-01
# 4   2017-12-02
# 5   2017-12-03
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ### **Day34: handling Date and Time**

# %% [markdown]
# Loading Data

# %%
date = pd.read_csv('/content/drive/MyDrive/day34-handling-date-and-time/orders.csv')
time = pd.read_csv('/content/drive/MyDrive/day34-handling-date-and-time/messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
date = date.drop(columns=['product_id', 'city_id', 'orders'])
date
# Out:
#            date
# 0    2019-12-10
# 1    2018-08-15
# 2    2018-10-23
# 3    2019-08-17
# 4    2019-01-06
# ..          ...
# 995  2018-10-08
# 996  2018-12-06
# 997  2019-05-07
# 998  2019-03-03
# 999  2019-10-15
#
# [1000 rows x 1 columns]

# %%
time = time.drop(columns='msg')
time
# Out:
#                     date
# 0    2013-12-15 00:50:00
# 1    2014-04-29 23:40:00
# 2    2012-12-30 00:21:00
# 3    2014-11-28 00:31:00
# 4    2013-10-26 23:11:00
# ..                   ...
# 995  2012-03-16 00:50:00
# 996  2014-01-23 23:14:00
# 997  2012-10-15 23:37:00
# 998  2012-06-21 23:34:00
# 999  2014-06-19 23:25:00
#
# [1000 rows x 1 columns]

# %% [markdown]
# Working with Dates

# %%
#Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %% [markdown]
# 1. Extract Year

# %%
date['date_year'] = date['date'].dt.year
date.head()
# Out:
#         date  date_year
# 0 2019-12-10       2019
# 1 2018-08-15       2018
# 2 2018-10-23       2018
# 3 2019-08-17       2019
# 4 2019-01-06       2019

# %% [markdown]
# 2. Extract Month

# %%
date['date_month_no'] = date['date'].dt.month
date.head()
# Out:
#         date  date_year  date_month_no
# 0 2019-12-10       2019             12
# 1 2018-08-15       2018              8
# 2 2018-10-23       2018             10
# 3 2019-08-17       2019              8
# 4 2019-01-06       2019              1

# %%
date['date_month_name'] = date['date'].dt.month_name()
date.head()
# Out:
#         date  date_year  date_month_no date_month_name
# 0 2019-12-10       2019             12        December
# 1 2018-08-15       2018              8          August
# 2 2018-10-23       2018             10         October
# 3 2019-08-17       2019              8          August
# 4 2019-01-06       2019              1         January

# %% [markdown]
# 3. Extract Day

# %%
date['date_day'] = date['date'].dt.day
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day
# 0 2019-12-10       2019             12        December        10
# 1 2018-08-15       2018              8          August        15
# 2 2018-10-23       2018             10         October        23
# 3 2019-08-17       2019              8          August        17
# 4 2019-01-06       2019              1         January         6

# %%
# day of week
date['date_dow'] = date['date'].dt.dayofweek
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6

# %%
# day of week - name
date['date_dow_name'] = date['date'].dt.day_name()
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name
# 0       Tuesday
# 1     Wednesday
# 2       Tuesday
# 3      Saturday
# 4        Sunday

# %%
# Is - Weekend ?
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Saturday']), 1, 0)
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name  date_is_weekend
# 0       Tuesday                0
# 1     Wednesday                0
# 2       Tuesday                0
# 3      Saturday                1
# 4        Sunday                1

# %% [markdown]
# Extract week of the year

# %%
date['date_week'] = date['date'].dt.isocalendar().week
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name  date_is_weekend  date_week
# 0       Tuesday                0         50
# 1     Wednesday                0         33
# 2       Tuesday                0         43
# 3      Saturday                1         33
# 4        Sunday                1          1

# %% [markdown]
# Extract Quater

# %%
date['date_quarter'] = date['date'].dt.quarter
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name  date_is_weekend  date_week  date_quarter
# 0       Tuesday                0         50             4
# 1     Wednesday                0         33             3
# 2       Tuesday                0         43             4
# 3      Saturday                1         33             3
# 4        Sunday                1          1             1

# %% [markdown]
# Extract Semester

# %%
date['semester'] = np.where(date['date_quarter'].isin([1, 2]), 1, 2)
date.head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December        10         1
# 1 2018-08-15       2018              8          August        15         2
# 2 2018-10-23       2018             10         October        23         1
# 3 2019-08-17       2019              8          August        17         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name  date_is_weekend  date_week  date_quarter  semester
# 0       Tuesday                0         50             4         2
# 1     Wednesday                0         33             3         2
# 2       Tuesday                0         43             4         2
# 3      Saturday                1         33             3         2
# 4        Sunday                1          1             1         1

# %% [markdown]
# Extract Time elapsed between dates

# %%
'''HH:MM:SS.microseconds'''
# Out:
# 'HH:MM:SS.microseconds'

# %%
import datetime

today = datetime.datetime.now()
today
# Out:
# datetime.datetime(2025, 12, 9, 13, 44, 57, 453758)

# %%
today - date['date']
# Out:
# 0     2191 days 13:44:57.453758
# 1     2673 days 13:44:57.453758
# 2     2604 days 13:44:57.453758
# 3     2306 days 13:44:57.453758
# 4     2529 days 13:44:57.453758
#                  ...
# 995   2619 days 13:44:57.453758
# 996   2560 days 13:44:57.453758
# 997   2408 days 13:44:57.453758
# 998   2473 days 13:44:57.453758
# 999   2247 days 13:44:57.453758
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      2191
# 1      2673
# 2      2604
# 3      2306
# 4      2529
#        ...
# 995    2619
# 996    2560
# 997    2408
# 998    2473
# 999    2247
# Name: date, Length: 1000, dtype: int64

# %%
np.timedelta64(30, 'D')
# Out:
# np.timedelta64(30,'D')

# %%
np.round((today - date['date']) / np.timedelta64(30, 'D'), 0)
# Out:
# 0      73.0
# 1      89.0
# 2      87.0
# 3      77.0
# 4      84.0
#        ...
# 995    87.0
# 996    85.0
# 997    80.0
# 998    82.0
# 999    75.0
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# **Working with Time**

# %%
time.head()
# Out:
#                   date
# 0  2013-12-15 00:50:00
# 1  2014-04-29 23:40:00
# 2  2012-12-30 00:21:00
# 3  2014-11-28 00:31:00
# 4  2013-10-26 23:11:00

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
# Converting to datetime
time['date'] = pd.to_datetime(time['date'])
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.9 KB

# %%
time['time'] = time['date'].dt.time
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date      time  hour  min  sec
# 0 2013-12-15 00:50:00  00:50:00     0   50    0
# 1 2014-04-29 23:40:00  23:40:00    23   40    0
# 2 2012-12-30 00:21:00  00:21:00     0   21    0
# 3 2014-11-28 00:31:00  00:31:00     0   31    0
# 4 2013-10-26 23:11:00  23:11:00    23   11    0

# %% [markdown]
# Time Difference

# %%
today - time['date']
# Out:
# 0     4377 days 12:54:57.453758
# 1     4241 days 14:04:57.453758
# 2     4727 days 13:23:57.453758
# 3     4029 days 13:13:57.453758
# 4     4426 days 14:33:57.453758
#                  ...
# 995   5016 days 12:54:57.453758
# 996   4337 days 14:30:57.453758
# 997   4802 days 14:07:57.453758
# 998   4918 days 14:10:57.453758
# 999   4190 days 14:19:57.453758
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# In seconds
"""
np.timedelta64(1, 's')
Represents a time duration of 1 second in NumPy’s timedelta64 format.
"""

np.round((today - time['date'])/np.timedelta64(1, 's'), 0)
# Out:
# 0      378219297.0
# 1      366473097.0
# 2      408461037.0
# 3      348153237.0
# 4      382458837.0
#           ...
# 995    433428897.0
# 996    374769057.0
# 997    414943677.0
# 998    424966257.0
# 999    362067597.0
# Name: date, Length: 1000, dtype: float64

# %%
# In Minutes

(today - time['date'])/ np.timedelta64(1, 'm')
# Out:
# 0      6.303655e+06
# 1      6.107885e+06
# 2      6.807684e+06
# 3      5.802554e+06
# 4      6.374314e+06
#            ...
# 995    7.223815e+06
# 996    6.246151e+06
# 997    6.915728e+06
# 998    7.082771e+06
# 999    6.034460e+06
# Name: date, Length: 1000, dtype: float64

# %%
# In hours
(today - time['date'])/ np.timedelta64(1, 'h')
# Out:
# 0      105060.915959
# 1      101798.082626
# 2      113461.399293
# 3       96709.232626
# 4      106238.565959
#            ...
# 995    120396.915959
# 996    104102.515959
# 997    115262.132626
# 998    118046.182626
# 999    100574.332626
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# ### **Pandas13 : Crosstab**

# %% [markdown]
# Before we dive into all things crosstabs, it's worth getting our definitions right. A crosstab (short for cross-tabulation) is a table used in statistics to display the relationship between two or more categorical variables. It allows you to examine how different categories or groups of variables intersect and how they are distributed within a dataset. In short, a crosstab summarizes categorical data, providing a quick and easy way to see patterns or associations between variables.

# %%
df = pd.read_excel('/content/drive/MyDrive/pandas13_pandas_crosstab/survey.xls')
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df['Nationality'], df['Handedness'])
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(df.Sex, df.Handedness)
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %% [markdown]
# Margins

# %%
pd.crosstab(df.Sex, df.Handedness, margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %% [markdown]
# Multi Index Column and Rows

# %%
pd.crosstab(df.Sex, [df.Handedness, df.Nationality], margins=True)
# Out:
# Handedness       Left                 Right           All
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2   5
# Male                1     1     2   1     0     1   1   7
# All                 2     2     2   1     1     1   3  12

# %%
pd.crosstab([df.Nationality, df.Sex], df.Handedness, margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %% [markdown]
# Normalize

# %%
pd.crosstab(df['Sex'], df['Handedness'], normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %%
pd.crosstab(df['Sex'], df['Handedness'], normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %% [markdown]
# Aggfunc and values
#
#
# aggfunc='mean' <br>
# aggfunc='sum' <br>
# aggfunc='median' <br>
# aggfunc='std' <br>
# aggfunc='count' <br>

# %%
pd.crosstab(df.Sex, df.Handedness, values=df['Age'], aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %%
pd.crosstab(df.Sex, df.Handedness, values=df['Age'], aggfunc=np.min)
# Out:
# /tmp/ipython-input-3912955032.py:1: FutureWarning: The provided callable <function min at 0x7c6d14003920> is currently using DataFrameGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   pd.crosstab(df.Sex, df.Handedness, values=df['Age'], aggfunc=np.min)
# Handedness  Left  Right
# Sex
# Female        31     18
# Male          22     19
